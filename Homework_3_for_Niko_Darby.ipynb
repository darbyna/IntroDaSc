# %% [markdown]
# # Homework Assignment 3 for Niko Darby

# %% [markdown]
# Write a Python notebook that generates a file containing the following data:
#
# - Email addresses
# - Phone numbers
# - Home Address
# - Person's name
# - Year born. Use realistic values.
# - Number of kids. Use realistic values.
# - Categorical variable: rent or own?
# - Annual income. Optional challenge: Use a non-uniform distribution
# - Number of speeding tickets in past year. Optional challenge: Use a non-uniform distribution
#     User of your notebook should be able to specify how many entities are to be generated.
#
# Generate data in 2 of the following 3 formats: XML, CSV, or JSON. Your choice!
#
# Order of columns in CSV is not relevant.

# %% [markdown]
# #### Cited Sources of Reference:
# - Information on Names Package Source: https://www.youtube.com/watch?v=E9bucW8Moco
# - RandInt Source: https://www.youtube.com/watch?v=ZzoTFD-wzdY&list=LLTd4XRKPjtkygA9JkJ_qu5w&index=1
# - Area Codes Source: https://www.areacodehelp.com/acus/us_area_codes.shtml
# - Street Names Source: https://catalog.data.gov/dataset/street-names-37fec/resource/d655cc82-c98f-450a-b9bb-63521c870503
# - Zip Codes Source: http://www.uszipcodelist.com/download.html
# #### Do know that the codes written below are in reference to the sources above. Niko Darby is not the original creator of the sources above. The function below is a creation of Niko Darby with assistance procured from the sources above:

# %%
import pandas as pd
import numpy as np
import names
from random import randint


def invormatocon_x():
    data = pd.DataFrame()
    emailz = input("Would you like a randomized email address?")
    domain_universe = ['gmail.com', 'yahoo.com', 'aol.com']
    
    
    try: 
        
        if emailz == 'Yes':
            np.random.seed(10)
            print(names.get_first_name(),'.', names.get_last_name(), '@', domain_universe[randint(0, len(domain_universe))])
            assert (emailz == 'Yes') == True
            maily = names.get_first_name(),'.', names.get_last_name(), '@', domain_universe[randint(0, len(domain_universe))]
            data['Email'] = ['x', 'x']
            data['Email'][0] = maily
        if emailz == 'No':
            input('Make your own email:')
        
                

    except: 
        return("Please insert 'Yes' or 'No'")
    next
    """Here you will be able to construct a randomized phone number"""
    
    digits_of_unity = input("Would you like a randomized phone number?")
    area_codes = [205, 251, 256, 334, 659, 938,907,480, 520, 602, 623, 928,479, 501, 870
    ,209, 213, 279, 310, 323, 341, 408, 415, 424, 442, 510, 530, 559, 562, 619, 626, 628, 650, 657, 661, 669, 707, 714, 747, 760, 805, 818, 820, 831, 840, 858, 909, 916, 925, 949, 951,303, 719, 720, 970,203, 475, 860, 959
    ,302,202,239, 305, 321, 352, 386, 407, 448, 561, 689, 727, 754, 772, 786, 813, 850, 863, 904, 941, 954
    ,229, 404, 470, 478, 678, 706, 762, 770, 912,808,208, 986,217, 224, 309, 312, 331, 447, 618, 630, 708, 773, 779, 815, 847, 872,219, 260, 317, 463, 574, 765, 812, 930,319, 515, 563, 641, 712, 316, 620, 785, 913
    ,270, 364, 502, 606, 859, 225, 318, 337, 504, 985,207,240, 301, 410, 443, 667,339, 351, 413, 508, 617, 774, 781, 857, 978
    ,231, 248, 269, 313, 517, 586, 616, 734, 810, 906, 947, 989, 218, 320, 507, 612, 651, 763, 952
    ,228, 601, 662, 769,314, 417, 573, 636, 660, 816,406,308, 402, 531, 702, 725, 775, 603
    ,201, 551, 609, 640, 732, 848, 856, 862, 908, 973, 505, 575, 212, 315, 332, 347, 516, 518, 585, 607, 631, 646, 680, 716, 718, 838, 845, 914, 917, 929, 934
    ,252, 336, 704, 743, 828, 910, 919, 980, 984,701,216, 220, 234, 326, 330, 380, 419, 440, 513, 567, 614, 740, 937, 405, 539, 580, 918, 458, 503, 541, 971,215, 223, 267, 272, 412, 445, 484, 570, 610, 717, 724, 814, 878, 787, 939, 401, 803, 839, 843, 854, 864, 605, 423, 615, 629, 731, 865, 901, 931, 210, 214, 254, 281, 325, 346, 361, 409, 430, 432, 469, 512, 682, 713, 726, 737, 806, 817,
                  830, 832, 903, 915, 936, 940, 945, 956, 972, 979, 385, 435, 801,802,276, 
                  434, 540, 571, 703, 757, 804,206, 253, 360, 425, 509, 564,202,304, 681,262,
                  414, 534, 608, 715, 920,307,800, 833, 844, 855, 866, 877, 888]
    
    try: 
        if digits_of_unity == 'Yes':
            print(area_codes[randint(0, len(area_codes))],'-', randint(100,1000), '-', randint(1000,10000))
            assert (digits_of_unity == 'Yes') == True
            areay = area_codes[randint(0, len(area_codes))],'-', randint(100,1000), '-', randint(1000,10000)
            data['Phone_Number'] = ['x', 'x']
            data['Phone_Number'][0] = areay
        if digits_of_unity == 'No':
            input('Make your own phone number:')
        

    except: 
        return("Please insert 'Yes' or 'No'")
    
    next 
    
    """Here you will be able to construct a randomized address"""
    
    quarters_for_life = input("Would you like a randomized address?")
    #place_aura = ['street', 'avenue', 'place', 'terrace']
    coordinate_fox = ['northwest', 'southeast', 'southwest', 'northeast']
    usa_street_names = pd.read_csv(r"street_names.csv")
    usa_street_names = usa_street_names['FullStreetName'].dropna()
    usa_zip_codes = pd.read_csv(r"zip_code_database.csv")
    usa_zip_codes = usa_zip_codes['zip'].dropna()
    
    

    try: 
        if quarters_for_life == 'Yes':
            print(randint(0,100000000), usa_street_names[randint(0, len(usa_street_names))], coordinate_fox[randint(0, len(coordinate_fox))], usa_zip_codes[randint(0, len(usa_zip_codes))] )
            assert (quarters_for_life == 'Yes') == True
            addrey = randint(0,100000000), usa_street_names[randint(0, len(usa_street_names))], coordinate_fox[randint(0, len(coordinate_fox))], usa_zip_codes[randint(0, len(usa_zip_codes))] 
            data['Address'] = ['x', 'x']
            data['Address'][0] = addrey
        if quarters_for_life == 'No':
            input('Make your own address:')


    except: 
        return("Please insert 'Yes' or 'No'")
    
    next 
    
    """Here you will be able to construct a randomized name"""
    
    dark_namez = input("Would you like a randomized name?")
    
    np.random.seed(10)
    try: 
        if dark_namez == 'Yes':
            np.random.seed(10)
            print(names.get_first_name(), names.get_last_name())
            assert (dark_namez == 'Yes') == True
            namey = names.get_first_name(), names.get_last_name()
            data['Name'] = ['x', 'x']
            data['Name'][0] = namey
        if dark_namez == 'No':
            input('Make your own name:')
        

    except: 
        return("Please insert 'Yes' or 'No'")
    
    next
    
    """Here you will be able to construct a randomized birthday"""
    
    seed_rise = input("Would you like a randomized birthday?")
    

    try: 
        if seed_rise == 'Yes':
            print(randint(1,13),'/', randint(1,32), '/', randint(1899, 2021))
            assert (seed_rise == 'Yes') == True
            birthy = randint(1,13),'/', randint(1,32), '/', randint(1899, 2021)
            data['Birthday'] = ['x', 'x']
            data['Birthday'][0] = birthy
        if seed_rise == 'No':
            input('Make your own birthday:')
        

    except: 
        return("Please insert 'Yes' or 'No'")
    
    next 
    
        
    """Here you will be able to construct a randomized F1 offspring count"""
    
    seed_pro = input("Would you like a randomized F1 offspring count?")
    

    try: 
        if seed_pro == 'Yes':
            print(randint(0,50))
            assert (seed_pro == 'Yes') == True
            offspring = randint(0,50)
            data['F1_Offspring'] = ['x', 'x']
            data['F1_Offspring'][0] = offspring
        if seed_pro == 'No':
            input('Make your own F1 offspring count:')
    

    except: 
        return("Please insert 'Yes' or 'No'")
    
    next 
    
    """Here you will be able to construct a randomized rent or own status"""
    
    own_o = input("Would you like a randomized rent or own status?")
    illumina = ['Rent', 'Own']

    try: 
        if own_o == 'Yes':
            print(illumina[randint(0, len(illumina))])
            assert (own_o == 'Yes') == True
            ownex = illumina[randint(0, len(illumina))]
            data['Ownership'] = ['x', 'x']
            data['Ownership'][0] = ownex
        if own_o == 'No':
            input('Make your own rent or own status:')

    except: 
        return("Please insert 'Yes' or 'No'")
    
    next
    
    """Here you will be able to construct a randomized annual income"""
    
    wealthix = input("Would you like a randomized annual income?")

    try: 
        if wealthix == 'Yes':
            print("$", randint(100,10000000), '.', '00')
            assert (wealthix == 'Yes') == True
            incomex = "$", randint(100,10000000), '.', '00'
            data['Annual_Income'] = ['x', 'x']
            data['Annual_Income'][0] = incomex
        if wealthix == 'No':
            input('Make your own annual income:')

    except: 
        return("Please insert 'Yes' or 'No'")
    
    next
    
    """Here you will be able to construct a randomized annual speeding ticket"""
    
    velocitox = input("Would you like a randomized annual speeding ticket ?")

    try: 
        if velocitox == 'Yes':
            print('You receive about', randint(0,500), 'speeding tickets per year')
            assert (velocitox == 'Yes') == True
            speedy = 'You receive about', randint(0,500), 'speeding tickets per year'
            data['Speeding_Ticket'] = ['x', 'x']
            data['Speeding_Ticket'][0] = speedy
        if velocitox == 'No':
            input('Make your own annual speeding tickets:')
        
    except: 
        return("Please insert 'Yes' or 'No'")
    
    return data.drop([1]).to_csv(r'C:/Users/admin/Desktop/darby_homework.csv'), data.drop([1])

# %%
invormatocon_x()
# Out:
# Would you like a randomized email address?Yes
# Samuel . Taylor @ gmail.com
# Would you like a randomized phone number?Yes
# 704 - 560 - 2084
# Would you like a randomized address?Yes
# 99835055 SUNNYDALE AVE southeast 67843
# Would you like a randomized name?Yes
# James Morrow
# Would you like a randomized birthday?Yes
# 13 / 2 / 1940
# Would you like a randomized F1 offspring count?Yes
# 18
# Would you like a randomized rent or own status?Yes
# Own
# Would you like a randomized annual income?Yes
# $ 6679302 . 00
# Would you like a randomized annual speeding ticket ?Yes
# You receive about 113 speeding tickets per year
# (None,
#                                  Email               Area_Code  \
#  0  (Cristopher, ., Doten, @, aol.com)  (386, -, 833, -, 7985)
#
#                                      Address               Name  \
#  0  (48556120, MARIPOSA ST, northwest, 3053)  (Ashley, Milhorn)
#
#                Birthday F1_Offspring Ownership        Annual_Income  \
# ...
